# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
path=Path("./resources/whale_returns.csv")
whale_returns=pd.read_csv(path,index_col="Date", parse_dates=True, infer_datetime_format=True)
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
count_nulls=whale_returns.isna().sum()
print(count_nulls)
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns.dropna()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
path=Path("./Resources/algo_returns.csv")
algo_returns=pd.read_csv(path, index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_returns.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
count_nulls=algo_returns.isna().sum()
count_nulls
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns.dropna()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
path=Path("./Resources/sp500_history.csv")
sp500_history=pd.read_csv(path, index_col="Date", parse_dates=True, infer_datetime_format=True)
sp500_history.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
print(sp500_history.dtypes)
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history["Close"]=sp500_history["Close"].str.replace("$","")
sp500_history.head()
# Out:
# C:\Users\luis.lu\Anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
sp500_history["Close"]=sp500_history["Close"].astype("float")
sp500_history.head()
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
# Calculate Daily Returns
sp500_history=sp500_history.sort_index(ascending=True)
sp500_returns=sp500_history.pct_change()
sp500_returns
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1649 rows x 1 columns]

# %%
# Drop nulls
sp500_returns=sp500_returns.dropna()

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns.columns=["SP500"]
sp500_returns.head()
# Out:
#                SP500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
daily_returns=pd.concat([whale_returns, algo_returns, sp500_returns], axis="columns", join="inner")
daily_returns=daily_returns.dropna()
daily_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2     SP500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
daily_returns.columns=["SOROS", "PC", "TGM", "BHI", "A1", "A2", "SP500"]
daily_returns.plot(rot=90)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns=(1+daily_returns).cumprod()
# Plot cumulative returns
cumulative_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
daily_returns.plot(kind="box", rot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
std=pd.DataFrame(daily_returns.std())
print(std)
std.plot(kind="bar", rot=90)
# Out:
#               0
# SOROS  0.007895
# PC     0.007023
# TGM    0.010894
# BHI    0.012919
# A1     0.007620
# A2     0.008342
# SP500  0.008554
# <AxesSubplot:>

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_std=daily_returns["SP500"].std()
print(sp500_std)
# Out:
# 0.008553731597758204

# %%
# Determine which portfolios are riskier than the S&P 500
index=daily_returns.columns
print(index)
print(".........Summary of the riskier portfoilios than the SP500 as the following..........")
risker=[]
for x in index:
    covariance=daily_returns[x].cov(daily_returns["SP500"])
    variance=daily_returns["SP500"].var()
    beta=covariance/variance
    
    if beta>1:
        risker.append(x)
        print(f"{x} has beta value greater than SP500, which is more volatile and riskier than SP500")
        
print(f"The riskier list = {risker}")

print("\n............The End..............")
# Out:
# Index(['SOROS', 'PC', 'TGM', 'BHI', 'A1', 'A2', 'SP500'], dtype='object')
# .........Summary of the riskier portfoilios than the SP500 as the following..........
# BHI has beta value greater than SP500, which is more volatile and riskier than SP500
# The riskier list = ['BHI']
#
# ............The End..............

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
astd=daily_returns.std()*np.sqrt(252)
print(astd)
# Out:
# SOROS    0.125335
# PC       0.111488
# TGM      0.172936
# BHI      0.205077
# A1       0.120967
# A2       0.132430
# SP500    0.135786
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
std_21=daily_returns.rolling(window=21).std()
print(std_21)
# Plot the rolling standard deviation
std_21.plot(rot=90)
# Out:
#                SOROS        PC       TGM       BHI        A1        A2  \
# Date
# 2015-03-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-03-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-03-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-03-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2015-03-09       NaN       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2019-04-16  0.006711  0.006224  0.007532  0.009731  0.005760  0.007053
# 2019-04-17  0.006773  0.006370  0.007574  0.009485  0.006229  0.007165
# 2019-04-18  0.006633  0.006303  0.007328  0.009475  0.005834  0.007172
# 2019-04-22  0.005915  0.006400  0.006197  0.009104  0.005831  0.007113
# 2019-04-23  0.004315  0.005695  0.004949  0.006602  0.005889  0.005582
#
#                SP500
# Date
# 2015-03-03       NaN
# 2015-03-04       NaN
# 2015-03-05       NaN
# ...

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation=daily_returns.corr()
# Display de correlation matrix
correlation
# Out:
#           SOROS        PC       TGM       BHI        A1        A2     SP500
# SOROS  1.000000  0.699914  0.561243  0.754360  0.321211  0.826873  0.837864
# PC     0.699914  1.000000  0.434479  0.545623  0.268840  0.678152  0.669732
# TGM    0.561243  0.434479  1.000000  0.424423  0.164387  0.507414  0.623946
# BHI    0.754360  0.545623  0.424423  1.000000  0.292033  0.688082  0.751371
# A1     0.321211  0.268840  0.164387  0.292033  1.000000  0.288243  0.279494
# A2     0.826873  0.678152  0.507414  0.688082  0.288243  1.000000  0.858764
# SP500  0.837864  0.669732  0.623946  0.751371  0.279494  0.858764  1.000000

# %%
print("\n......Heat Map..........")
import seaborn as sns
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# ......Heat Map..........
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance=daily_returns["SOROS"].rolling(window=20).cov(daily_returns["SP500"])
print(covariance)
covariance.plot()
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.000042
# 2019-04-17    0.000042
# 2019-04-18    0.000035
# 2019-04-22    0.000014
# 2019-04-23    0.000015
# Length: 1043, dtype: float64
# <AxesSubplot:xlabel='Date'>

# %%
# Calculate variance of S&P 500
variance=daily_returns["SP500"].rolling(window=20).var()
print(variance)
variance.plot()
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.000044
# 2019-04-17    0.000044
# 2019-04-18    0.000039
# 2019-04-22    0.000017
# 2019-04-23    0.000019
# Name: SP500, Length: 1043, dtype: float64
# <AxesSubplot:xlabel='Date'>

# %%
# Computing beta
print("......the Beta of SOROS.......")
beta=covariance/variance
print(beta)
# Plot beta trend
beta.plot(figsize=(20,10), title="Beta of SOROS")
# Out:
# ......the Beta of SOROS.......
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.951768
# 2019-04-17    0.945080
# 2019-04-18    0.884006
# 2019-04-22    0.828469
# 2019-04-23    0.799509
# Length: 1043, dtype: float64
# <AxesSubplot:title={'center':'Beta of SOROS'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
daily_returns.ewm(halflife=21).mean()
# Out:
#                SOROS        PC       TGM       BHI        A1        A2  \
# Date
# 2015-03-03 -0.001266 -0.004981 -0.000496 -0.006569 -0.001942 -0.000949
# 2015-03-04  0.000511 -0.000802 -0.001532 -0.001089 -0.005320  0.000761
# 2015-03-05  0.001718  0.000878 -0.000193  0.001603 -0.003817  0.001988
# 2015-03-06 -0.000808 -0.000291 -0.002369 -0.002256 -0.004116 -0.001542
# 2015-03-09 -0.000511  0.000673 -0.000616 -0.002128 -0.004400 -0.000935
# ...              ...       ...       ...       ...       ...       ...
# 2019-04-16  0.001480  0.000448 -0.000813  0.001862  0.000912  0.001364
# 2019-04-17  0.001338  0.000223 -0.000930  0.001906  0.000548  0.001150
# 2019-04-18  0.001341  0.000256 -0.000881  0.001907  0.000511  0.001073
# 2019-04-22  0.001214  0.000009 -0.000971  0.001809  0.000516  0.000975
# 2019-04-23  0.001407  0.000122 -0.000729  0.002182  0.000661  0.001256
#
#                SP500
# Date
# 2015-03-03 -0.004539
# 2015-03-04 -0.004462
# 2015-03-05 -0.002514
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratio=((daily_returns.mean()-daily_returns["SP500"].mean())*252)/(daily_returns.std()*np.sqrt(252))
sharpe_ratio
# Out:
# SOROS   -0.345907
# PC      -1.273125
# TGM     -0.630067
# BHI      0.192576
# A1       0.650964
# A2      -0.163336
# SP500    0.000000
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind="bar", figsize=(20,10), title="Sharpe Ratio")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratio'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---

# %%
# Create Custom Portfolio

# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500. 

# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock, 2nd and 3rd stocks. then combine them into one DataFrame. reorganize the columns by having a column per stock.
apple=pd.read_csv(Path("./Resources/aapl_historical.csv"), index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
google=pd.read_csv(Path("./Resources/goog_historical.csv"), index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
cost=pd.read_csv(Path("./Resources/cost_historical.csv"), index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
google=google.rename(columns={"NOCP":"google"})
apple=apple.rename(columns={"NOCP":"apple"})
cost=cost.rename(columns={"NOCP":"cost"})
stocks=pd.concat([apple, google, cost], axis="columns", join="inner")
stocks=stocks.drop(columns="Symbol")
stocks.sort_index(inplace=True)
stocks
# Out:
#              apple   google    cost
# Trade DATE
# 2018-05-11  188.59  1098.26  195.76
# 2018-05-14  188.15  1100.20  195.88
# 2018-05-15  186.44  1079.23  195.48
# 2018-05-16  188.18  1081.77  198.71
# 2018-05-17  186.99  1078.59  199.60
# ...            ...      ...     ...
# 2019-05-03  211.75  1185.40  244.62
# 2019-05-06  208.48  1189.39  244.23
# 2019-05-07  202.86  1174.10  240.18
# 2019-05-08  202.90  1166.27  241.34
# 2019-05-09  200.72  1162.38  243.47
#
# [250 rows x 3 columns]

# %%
# Reset Date index
index=stocks.index
index
# Out:
# DatetimeIndex(['2018-05-11', '2018-05-14', '2018-05-15', '2018-05-16',
#                '2018-05-17', '2018-05-18', '2018-05-21', '2018-05-22',
#                '2018-05-23', '2018-05-24',
#                ...
#                '2019-04-26', '2019-04-29', '2019-04-30', '2019-05-01',
#                '2019-05-02', '2019-05-03', '2019-05-06', '2019-05-07',
#                '2019-05-08', '2019-05-09'],
#               dtype='datetime64[ns]', name='Trade DATE', length=250, freq=None)

# %%
# Calculate daily returns
stockreturn=stocks.pct_change()
stockreturn
# Out:
#                apple    google      cost
# Trade DATE
# 2018-05-11       NaN       NaN       NaN
# 2018-05-14 -0.002333  0.001766  0.000613
# 2018-05-15 -0.009088 -0.019060 -0.002042
# 2018-05-16  0.009333  0.002354  0.016523
# 2018-05-17 -0.006324 -0.002940  0.004479
# ...              ...       ...       ...
# 2019-05-03  0.012431  0.019602  0.007953
# 2019-05-06 -0.015443  0.003366 -0.001594
# 2019-05-07 -0.026957 -0.012855 -0.016583
# 2019-05-08  0.000197 -0.006669  0.004830
# 2019-05-09 -0.010744 -0.003335  0.008826
#
# [250 rows x 3 columns]

# %%
# Drop NAs
stockreturn=stockreturn.dropna().sort_index(ascending=True)
# Display sample data
stockreturn.sample()
# Out:
#                apple    google      cost
# Trade DATE
# 2018-12-10  0.006588  0.002865 -0.009784

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
totalstockreturn=pd.DataFrame(stockreturn.dot(weights))

# %%
totalstockreturn.columns=["combined"]

# %%
# Display sample data
totalstockreturn.head()
# Out:
#             combined
# Trade DATE
# 2018-05-14  0.000015
# 2018-05-15 -0.010064
# 2018-05-16  0.009403
# 2018-05-17 -0.001595
# 2018-05-18 -0.006061

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combinedreturns=pd.concat([stockreturn, totalstockreturn], axis="columns", join="inner")
combinedreturns
# Out:
#                apple    google      cost  combined
# Trade DATE
# 2018-05-14 -0.002333  0.001766  0.000613  0.000015
# 2018-05-15 -0.009088 -0.019060 -0.002042 -0.010064
# 2018-05-16  0.009333  0.002354  0.016523  0.009403
# 2018-05-17 -0.006324 -0.002940  0.004479 -0.001595
# 2018-05-18 -0.003637 -0.011339 -0.003206 -0.006061
# ...              ...       ...       ...       ...
# 2019-05-03  0.012431  0.019602  0.007953  0.013329
# 2019-05-06 -0.015443  0.003366 -0.001594 -0.004557
# 2019-05-07 -0.026957 -0.012855 -0.016583 -0.018798
# 2019-05-08  0.000197 -0.006669  0.004830 -0.000547
# 2019-05-09 -0.010744 -0.003335  0.008826 -0.001751
#
# [249 rows x 4 columns]

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combinedreturns.isna().sum()
combinedreturns.describe()
# Out:
#             apple      google        cost    combined
# count  249.000000  249.000000  249.000000  249.000000
# mean     0.000426    0.000366    0.000964    0.000585
# std      0.018706    0.016602    0.013186    0.013245
# min     -0.099607   -0.076966   -0.085868   -0.049762
# 25%     -0.008068   -0.007150   -0.004171   -0.004724
# 50%      0.001326    0.000101    0.002780    0.001675
# 75%      0.008994    0.009613    0.007123    0.006724
# max      0.070422    0.064780    0.050879    0.060226

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
astd=combinedreturns.std()*np.sqrt(252)
astd
# Out:
# apple       0.296955
# google      0.263554
# cost        0.209320
# combined    0.210262
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
astd21days=combinedreturns.rolling(window=21).std()
# Plot rolling standard deviation
astd21days.plot(title="20 Days Rolling Standard Deviation")
# Out:
# <AxesSubplot:title={'center':'20 Days Rolling Standard Deviation'}, xlabel='Trade DATE'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation=astd21days.corr()
correlation
# Out:
#              apple    google      cost  combined
# apple     1.000000  0.852192  0.727557  0.948615
# google    0.852192  1.000000  0.709679  0.910534
# cost      0.727557  0.709679  1.000000  0.857972
# combined  0.948615  0.910534  0.857972  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
comparereturns=pd.concat([combinedreturns, sp500_returns], axis="columns", join="inner")
comparereturns.isna().sum()
# Out:
# apple       0
# google      0
# cost        0
# combined    0
# SP500       0
# dtype: int64

# %%
comparereturns

# %%
sharpe_ratio=((comparereturns.mean()-comparereturns["SP500"].mean())*252)/(comparereturns.std()*np.sqrt(252))
sharpe_ratio
# Out:
# apple       0.191393
# google      0.365995
# cost        0.825033
# combined    0.512669
# SP500       0.000000
# dtype: float64

# %%
stocks=comparereturns.columns
stocks=stocks.drop(stocks[3:])
stocks
# Out:
# Index(['apple', 'google', 'cost'], dtype='object')

# %%
for y in stocks:
    covariance=comparereturns[y].rolling(window=60).cov(comparereturns["SP500"])
    variance=comparereturns["SP500"].rolling(window=60).var()
    beta=covariance/variance
    beta=beta.dropna()
    print(f"{y} has the beta value {beta}")
    beta.plot(figsize=(20,10), title="Apple, Google and Cost have the following plot of beta values", legend=True, label=y)
# Out:
# apple has the beta value 2018-08-07    1.022332
# 2018-08-08    1.022498
# 2018-08-09    0.998270
# 2018-08-10    0.992411
# 2018-08-13    0.963216
#                 ...
# 2019-04-16    1.579042
# 2019-04-17    1.527550
# 2019-04-18    1.528001
# 2019-04-22    1.526811
# 2019-04-23    1.466646
# Length: 178, dtype: float64
# google has the beta value 2018-08-07    1.576980
# 2018-08-08    1.575708
# 2018-08-09    1.529765
# 2018-08-10    1.537075
# 2018-08-13    1.527649
#                 ...
# 2019-04-16    1.352755
# 2019-04-17    1.290265
# 2019-04-18    1.289913
# 2019-04-22    1.287190
# 2019-04-23    1.275512
# Length: 178, dtype: float64
# cost has the beta value 2018-08-07    0.409169
# 2018-08-08    0.408472
# 2018-08-09    0.442053
# 2018-08-10    0.369109
# 2018-08-13    0.380497
#                 ...
# 2019-04-16    0.588924
# 2019-04-17    0.596584
# 2019-04-18    0.597739
# 2019-04-22    0.599822
# 2019-04-23    0.645453
# Length: 178, dtype: float64

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratio=((comparereturns.mean()-comparereturns["SP500"].mean())*252)/(comparereturns.std()*np.sqrt(252))
sharpe_ratio
# Out:
# apple       0.191393
# google      0.365995
# cost        0.825033
# combined    0.512669
# SP500       0.000000
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind="bar", figsize=(10,5), title="Sharpe Ratio of Stocks")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratio of Stocks'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %% [markdown]
# **Answer:**
# The overall sharpe ratio and individual sharpe ratioes are below one but above zero. That means the risk - adjusted returns are just so so for all the stocks.
